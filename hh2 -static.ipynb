# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh = pd.read_csv('data/hh_1000.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
hh.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     999 non-null    object
#  1   ЗП                               999 non-null    object
#  2   Ищет работу на должность:        999 non-null    object
#  3   Город, переезд, командировки     999 non-null    object
#  4   Занятость                        999 non-null    object
#  5   График                           999 non-null    object
#  6   Опыт работы                      995 non-null    object
#  7   Последнее/нынешнее место работы  999 non-null    object
#  8   Последняя/нынешняя должность     999 non-null    object
#  9   Образование и ВУЗ                999 non-null    object
#  10  Обновление резюме                999 non-null    object
#  11  Авто                             999 non-null    object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
hh.describe()
# Out:
#                                      Пол, возраст          ЗП  \
# count                                         999         999
# unique                                        950         115
# top     Мужчина ,  40 лет , родился 2 января 1979  40000 руб.
# freq                                            3          96
#
#        Ищет работу на должность:  \
# count                        999
# unique                       564
# top      Системный администратор
# freq                          70
#
#                              Город, переезд, командировки         Занятость  \
# count                                                 999               999
# unique                                                734                24
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                   24               630
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def education(ed):
    ed_lst = ed.split()
    ed_3 = ' '.join(ed_lst[:3])
    
    if 'Высшее' in ed_3:
        return "высшее"
    elif 'Неоконченное' in ed_3:
        return "неоконченное высшее"
    elif 'специальное' in ed_3:
        return "среднее специальное"
    elif 'Среднее' in ed_3:
        return "среднее"

hh['Образование'] = hh['Образование и ВУЗ'].apply(education)

hh.drop('Образование и ВУЗ', axis=1, inplace=True)

hh.info()

hh['Образование'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     999 non-null    object
#  1   ЗП                               999 non-null    object
#  2   Ищет работу на должность:        999 non-null    object
#  3   Город, переезд, командировки     999 non-null    object
#  4   Занятость                        999 non-null    object
#  5   График                           999 non-null    object
#  6   Опыт работы                      995 non-null    object
#  7   Последнее/нынешнее место работы  999 non-null    object
#  8   Последняя/нынешняя должность     999 non-null    object
#  9   Обновление резюме                999 non-null    object
#  10  Авто                             999 non-null    object
#  11  Образование                      999 non-null    object
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
def gender(gen):
    gen_lst = gen.split(' , ')
    if 'Мужчина' in gen_lst[0]:
        return 'М'
    if 'Женщина' in gen_lst[0]:
        return 'Ж'

def age(ag):
    ag_lst = ag.split(' , ')
    ag_str = ''.join(ag_lst[1])
    return int(ag_str.split()[0])


hh['Пол'] = hh['Пол, возраст'].apply(gender)
hh['Возраст'] = hh['Пол, возраст'].apply(age)

print(hh['Пол'].value_counts(normalize=True) * 100, end='\n\n')
print(round(hh['Возраст'].mean(), 1), end='\n\n')

hh.drop('Пол, возраст', axis=1, inplace=True)

print(hh.info())
# Out:
# М    80.980981
# Ж    19.019019
# Name: Пол, dtype: float64
#
# 32.5
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               999 non-null    object
#  1   Ищет работу на должность:        999 non-null    object
#  2   Город, переезд, командировки     999 non-null    object
#  3   Занятость                        999 non-null    object
#  4   График                           999 non-null    object
#  5   Опыт работы                      995 non-null    object
#  6   Последнее/нынешнее место работы  999 non-null    object
#  7   Последняя/нынешняя должность     999 non-null    object
#  8   Обновление резюме                999 non-null    object
#  9   Авто                             999 non-null    object
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def education(ed):
    if pd.isna(ed) or ed == "Не указано":
        return np.nan
    
    month_list = ['месяц', 'месяца', 'месяцев']
    year_list = ['года', 'год', 'лет']
    month = 0
    year = 0

    ed_list = ed.split()[2:6]
    
    for i in range(len(ed_list)):
        if ed_list[i] in month_list:
            month = ed_list[i-1]
        if ed_list[i] in year_list:
            year = ed_list[i-1]

    return int(year)*12 + int(month)

hh['Опыт работы (месяц)'] = hh['Опыт работы'].apply(education)

print(hh['Опыт работы (месяц)'].median(), end='\n\n')

hh.drop('Опыт работы', axis=1, inplace=True)

print(hh.info())
# Out:
# 103.0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               999 non-null    object
#  1   Ищет работу на должность:        999 non-null    object
#  2   Город, переезд, командировки     999 non-null    object
#  3   Занятость                        999 non-null    object
#  4   График                           999 non-null    object
#  5   Последнее/нынешнее место работы  999 non-null    object
#  6   Последняя/нынешняя должность     999 non-null    object
#  7   Обновление резюме                999 non-null    object
#  8   Авто                             999 non-null    object
#  9   Образование                      999 non-null    object
#  10  Пол                              999 non-null    object
#  11  Возраст                          999 non-null    int64
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
def city(city_str):
    million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']

    city_lst = city_str.split(' , ')
    if city_lst[0] == "Москва":
        return "Москва"
    elif city_lst[0] == "Санкт-Петербург":
        return "Санкт-Петербург"
    elif city_lst[0] in million_cities:
        return "город-миллионник"
    else:
        return "другие"

def ready_to_move(move):
    if move.find('не готов к переезду')>0 or move.find('не готова к переезду')>0:
        return False
    else:
        return True
    

def ready_to_btrip(btrip='Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург)'):
    btrip_lst = btrip.split(' , ')
    
    flag = 0
    
    for i in btrip_lst:
        if 'командировкам' in i:
            flag += 1
            if 'не' in i:
                return False
            else:
                return True
            
    if flag == 0:
        return False

ready_to_btrip()


hh['Город'] = hh['Город, переезд, командировки'].apply(city)
hh['Готовность к переезду'] = hh['Город, переезд, командировки'].apply(ready_to_move)
hh['Готовность к командировкам'] = hh['Город, переезд, командировки'].apply(ready_to_btrip)

counter = 0
for ind in hh.index:
    if hh['Готовность к переезду'][ind] and hh['Готовность к командировкам'][ind]:
        counter += 1

print("Командировки и переезд: ", counter/hh.shape[0] * 100, end='\n\n')

print(hh['Город'].value_counts(normalize=True) * 100, end='\n\n')
hh.drop('Город, переезд, командировки', axis=1, inplace=True)
print(hh.info())
# Out:
# Командировки и переезд:  31.53153153153153
#
# другие              37.537538
# Москва              36.436436
# город-миллионник    15.815816
# Санкт-Петербург     10.210210
# Name: Город, dtype: float64
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               999 non-null    object
#  1   Ищет работу на должность:        999 non-null    object
#  2   Занятость                        999 non-null    object
#  3   График                           999 non-null    object
#  4   Последнее/нынешнее место работы  999 non-null    object
#  5   Последняя/нынешняя должность     999 non-null    object
#  6   Обновление резюме                999 non-null    object
#  7   Авто                             999 non-null    object
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
#
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# print(hh['Занятость'].unique())
# print(hh['График'].unique())

hh['полная занятость'] = hh['Занятость'].apply(lambda x: x.find('полная занятость') >= 0)
hh['частичная занятость'] = hh['Занятость'].apply(lambda x: x.find('частичная занятость') >= 0)
hh['проектная работа'] = hh['Занятость'].apply(lambda x: x.find('проектная работа') >= 0)
hh['волонтерство'] = hh['Занятость'].apply(lambda x: x.find('волонтерство') >= 0)
hh['стажировка'] = hh['Занятость'].apply(lambda x: x.find('стажировка') >= 0)

hh['гибкий график'] = hh['График'].apply(lambda x: x.find('гибкий график') >= 0)
hh['полный день'] = hh['График'].apply(lambda x: x.find('полный день') >= 0)
hh['сменный график'] = hh['График'].apply(lambda x: x.find('сменный график') >= 0)
hh['вахтовый метод'] = hh['График'].apply(lambda x: x.find('вахтовый метод') >= 0)
hh['удаленная работа'] = hh['График'].apply(lambda x: x.find('удаленная работа') >= 0)

hh.drop('Занятость', axis=1, inplace=True)
hh.drop('График', axis=1, inplace=True)
hh.info()

counter = 0
for ind in hh.index:
    if hh['проектная работа'][ind] and hh['волонтерство'][ind]:
        counter += 1
print("Проектная работа и Волонтерство: ", counter, end='\n\n')

counter = 0
for ind in hh.index:
    if hh['вахтовый метод'][ind] and hh['гибкий график'][ind]:
        counter += 1
print("Вахтовый метод и Гибкий график: ", counter, end='\n\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               999 non-null    object
#  1   Ищет работу на должность:        999 non-null    object
#  2   Последнее/нынешнее место работы  999 non-null    object
#  3   Последняя/нынешняя должность     999 non-null    object
#  4   Обновление резюме                999 non-null    object
#  5   Авто                             999 non-null    object
#  6   Образование                      999 non-null    object
#  7   Пол                              999 non-null    object
#  8   Возраст                          999 non-null    int64
#  9   Опыт работы (месяц)              995 non-null    float64
#  10  Город                            999 non-null    object
#  11  Готовность к переезду            999 non-null    bool
# ...

# %% [markdown]
# 6. Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
exch = pd.read_csv('data/ExchangeRates.csv')

# Преобразовываем стобцы в формат datetime
exch.date = pd.to_datetime(exch.date).dt.date
hh['Обновление резюме'] = pd.to_datetime(hh['Обновление резюме']).dt.date

# Признак с суммами зарплат
hh['ЗП сум'] = hh['ЗП'].apply(lambda x: float(x.split()[0]))

# Словарь для перевода валют в ИСО формат
# И создание новго признака с обозначением валюты 
dic = {
    'грн.':'UAH',
    'USD':'USD',
    'EUR':'EUR',
    'бел.руб.':'BYN',
    'KGS':'KGS',
    'сум':'UZS',
    'AZN':'AZN',
    'KZT':'KZT',
    'руб.':'RUB',
    }

hh['Валюта ISO'] = hh['ЗП'].apply(lambda x: x.split()[1])
hh['Валюта ISO'].replace(dic, inplace=True)

# Созадем новый дф объединяя дф с резюме и курсами
hh_merge = hh.merge(
    exch,
    left_on=['Валюта ISO', 'Обновление резюме'], 
    right_on=['currency', 'date'],
    how='left'
)

# Заполняем пропуски
hh_merge['close'] = hh_merge['close'].fillna(1)
hh_merge['proportion'] = hh_merge['proportion'].fillna(1)

# Вычисляем новый признак - сумма ЗП в рублях
hh['ЗП (руб)'] = hh_merge['close'] * hh_merge['ЗП сум'] / hh_merge['proportion']

# Удаляем временые признаки
hh.drop(['ЗП', 'ЗП сум', 'Валюта ISO'], axis=1, inplace=True)

print(hh.info())
print(hh['ЗП (руб)'].median())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        999 non-null    object
#  1   Последнее/нынешнее место работы  999 non-null    object
#  2   Последняя/нынешняя должность     999 non-null    object
#  3   Обновление резюме                999 non-null    object
#  4   Авто                             999 non-null    object
#  5   Образование                      999 non-null    object
#  6   Пол                              999 non-null    object
#  7   Возраст                          999 non-null    int64
#  8   Опыт работы (месяц)              995 non-null    float64
#  9   Город                            999 non-null    object
#  10  Готовность к переезду            999 non-null    bool
#  11  Готовность к командировкам       999 non-null    bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = px.histogram(
    hh,
    x="Возраст",
    # nbins=50,
    title='Распределение резюме по возрасту, гистограмма',
    )
fig.show()

fig = px.box(
    hh,
    x="Возраст",
    title='Распределение резюме по возрасту, коробчатая диаграмма',
    )
fig.show()

print(hh['Возраст'].mode())
# Out:
# 0    26
# Name: Возраст, dtype: int64

# %% [markdown]
# Средний возраст соискателя 31 год. При этом мода по выборке - 30
#
# Предельные значения: min - 14, max - 100
#
# Если смотреть большинство по межквартильному размаху, то мы видим, что это от 27 до 36 лет
#
# Согласно теории Тьюки мы видим выбросы справа начиная от 50 лет. При этом конечно не факт, что эти данные не верные. Также есть зачение в 100 лет, которое скорее всего либо ошибка при заполнении, либо намерненное не желание указывать настоящий возраст.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = px.histogram(
    hh,
    x="Опыт работы (месяц)",
    # nbins=110,
    title='Распределение резюме по опыту работы в месяцах, гистограмма',
    )
fig.show(renderer="png")

fig = px.box(
    hh,
    x="Опыт работы (месяц)",
    title='Распределение резюме по опыту работы в месяцах, коробчатая диаграмма',
    )
fig.show(renderer="svg")

print(hh['Опыт работы (месяц)'].mode())

print(hh['Опыт работы (месяц)'].max())
# Out:
# 0    105.0
# Name: Опыт работы (месяц), dtype: float64
# 510.0

# %% [markdown]
# Мода по нашей выборке - 81 месяц или же 6 лет и 9 месяцев опыта работы
#
# Минимальное значение, которые мы видим это 1 месяц, максимальное 1188 месяцев.
#
# Опыт большинства находится в промежутке от 57 до 154 месяцев. Т.е. 4 года 9 месяцев - 12 лет 10 месяцев
#
# Метод Тьюки в коробчатой дигармме предлагает нам считать выбросами все, что больше 300 месяцев или 25 лет. Теоритически такой опты вполне возможен. При этом мы видим такие значения как 1188 месяцев, что соответствует 99 годам. Это уже точно не корректные данные.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака ЗП? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = px.histogram(
    hh,
    x="ЗП (руб)",
    # nbins=100,
    title='Распределение резюме по желаемой ЗП, гистограмма',
    )
fig.show()

fig = px.box(
    hh,
    x="ЗП (руб)",
    title='Распределение резюме по желаемой ЗП, коробчатая диаграмма',
    )
fig.show()

print(hh['ЗП (руб)'].mode())

print(hh['ЗП (руб)'].max())
print(hh['ЗП (руб)'].min())
# Out:
# 0    40000.0
# Name: ЗП (руб), dtype: float64
# 645171.0
# 160.0

# %% [markdown]
# Мода распределения, то есть самое часто встрчающееся значение в признаке ЗП это 50.000
#
# Значения признака лежат в диапазоне от 1 рубля до 24.304.876 рублей
#
# Большая часть значений лежит в диапазоне от 37.000 до 95.000
#
# Довольно сильно выбиваются значения выше 500.000 и даже есть 5 значений выше 1.000.000 рублей.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
mask = hh['ЗП (руб)'] < 1_000_000
hh_filtred = hh[mask]
hh_filtred.groupby('Образование')['ЗП (руб)'].median()
fig = px.scatter(
    hh_filtred,
    x="ЗП (руб)",
    y="Образование",
    title='Зависимость желаемой ЗП от уровня образования',
    )
fig.show()

# %% [markdown]
# Если посмотреть по категориям образования, то мы получим следующие медианные значения:
#
# * высшее                 60000.0
# * неоконченное высшее    50000.0
# * среднее                40000.0
# * среднее специальное    40000.0
#
# То есть на наибольшую зарплату расчитывают соискатели с высшим образованием, а на наименьшую те у кого среднее или среднее специлаьное образование
#
# Разница в желаемой зп здесь видна и измеряется десятками тысяч, так что это признак важен при прогнозировании

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
fig = plt.figure(figsize=(12, 8))
barplot = sns.barplot(
    data=hh_filtred,
    x="ЗП (руб)",
    y="Город",
)
barplot.set_title('Зависимость желаемой ЗП от города');

print(hh_filtred.groupby('Город')['ЗП (руб)'].median(), end='\n\n')
print(hh_filtred.groupby('Город')['ЗП (руб)'].max())
# Out:
# Город
# Москва              80000.0
# Санкт-Петербург     60000.0
# город-миллионник    45000.0
# другие              40000.0
# Name: ЗП (руб), dtype: float64
#
# Город
# Москва              639602.00
# Санкт-Петербург     645171.00
# город-миллионник    399583.25
# другие              400000.00
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# Медианные ЗП по городам как мы видим такие:
#
# * Москва              85000.0
# * Санкт-Петербург     60000.0
# * город-миллионник    40000.0
# * другие              40000.0
#
# Получается, что большее количество людей в качестве желаемой указывает зарплату, которая находится ближе к максимуму размаха по его региону в целом.
#
# Опять же мы видим, что Москва с отрывом имеет большие пожелание по ЗП чем другие города, за Москвой уже идет СПб с отставанием в 25.000, во всех остальных городах, включая милионники, зарпалтные ожидания еще на 20.000 меньше. Так что признак города важен для предсказания зарплаты.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
hh_gr = hh.groupby(by=["Готовность к командировкам", 'Готовность к переезду'], as_index=False).median()

fig = px.bar(
            hh_gr,
            x="Готовность к командировкам",
            y="ЗП (руб)",
            color='Готовность к переезду',
            barmode='group',
            title='Медианная ЗП, переезды и командировки'
             )
fig.show()

# %% [markdown]
# Категории распредлились следующия образом от большей желаемой зарплаыт к меньшей:
# * Готовы и к переезду и к комнадировкам
# * Готовы только к командировкам
# * Готовы только к переезду
# * Не готовы ни к переезду, ни к командировкам

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
hh_gr = hh.groupby(by=["Образование", 'Возраст'], as_index=False).median()

import plotly.graph_objects as go

fig = go.Figure(data=go.Heatmap(
                   x=hh_gr['Возраст'],
                   y=hh_gr['Образование'],
                   z=hh_gr['ЗП (руб)'],
                   hoverongaps = False,
                   colorscale='Viridis'
                   )
                )
fig.update_layout(title='Медианная ЗП, возраст и образование')
fig.show()

# %% [markdown]
# Лучше всего прослеживаются рост желаемых зарплат с возрастом в категориях 'высшее' и 'неконченное высшее'.
# * Высшее - максимальную зарплату желают в 40-42 года
# * Неоконченно высшее, чуть позже в 43 года
# Можно преположить, что это происходит из-за того, что многие к этому возрасту набираются оптыа и хотят больших ЗП.
#
# В категории 'среднее' также есть небольшой рост к 40 годам, но более сглаженный
#
# В категории "среднее специальное" все распределение выглядит более ровным.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
hh["Опыт работы (год)"] = round(hh["Опыт работы (месяц)"] / 12, 1)
hh["Опыт работы (год)"] 

fig = px.scatter(hh, x="Возраст", y="Опыт работы (год)", title='Возраст и Опыт работы')
fig.add_shape(type='line',
              x0=0, y0=0, 
              x1=100, y1=100)

fig.show()

# hh.drop('Опыт работы (год)', axis=1, inplace=True)

# %% [markdown]
# Как мы видим данные располагаются столбцами, которые в целом показывают рост опыта с возрастом соискателей.
#
# Также мы явно видим 7 точек над отрекзком (0,0) (100,100). Это говорит о том, что данные точки являются выбросами, так как опыт работы конечно не может быть больше возраста самого человека. Также вблизи линии есть точки, если верить которым, то соискатели начала свой карьерный путь в 5 лет.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# Сгрпируем данные, возьмем для работы дф с ЗП до 1_000_000
hh_gr = hh_filtred.groupby(by=["Пол", 'Возраст'], as_index=False).median()

fig = px.box(
                hh_gr,
                x="ЗП (руб)",
                y="Пол",
                # points="all",
                title='Пол и зарплатные ожидания',
                color='Пол'
                )

fig.show()

# %% [markdown]
# Давайте рассмотрим медианные зарплатные ожидания в зависимости от пола респондента.
#
# Как мы видим эти категории радикальыным образом различаются
#
# Средняя ожидаемя ЗП у Женщин - 46.000, а у Мужчин 65.000. То есть разрыв 19.000 рублей
#
# Посмотрим на распредение у большинства. Женцины - от 33.000 до 50.000. Мужчины от 51.000 до 80.000
# То есть Макимальные ожидания большинства женщин находятся на нижней границе зарплатных ожиданий большинства мужчин.

# %%
fig = px.scatter(
                    hh_filtred,
                    x="Обновление резюме", 
                    y="ЗП (руб)", 
                    color="ЗП (руб)",
                    title='Распределение резюме по времени и зарплате'
                    )
fig.show()

# %% [markdown]
# Это распредление обновления резюме по временному ряду, где точки по оси Y распологаются в зависимости от желаемой зарплаты. Тут сложно увидеть какую-то особеннюу зависимость в этой раскладке, но в то же время, мы видим что обновления тяготеют к некторым вертикальынм линиям. Особенно хорошо это заметно в правой части графика, начиная с мая 2019го года. Неизвестно с чем это связано. Возможно особенность сбора данных, брались только несколько первых дней месяца.
#
# Отмечу также, что цвет в данном случае не несет особой смысловой нагрузки, так как по сути дублирует информацию оси Y.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
dupl_columns = list(hh.columns)

mask = hh.duplicated(subset=dupl_columns)
hh_duplicates = hh[mask]
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}')

hh.drop_duplicates(subset=dupl_columns, inplace=True)
print(f'Результирующее число записей: {hh.shape[0]}')
# Out:
# Число найденных дубликатов: 3
# Результирующее число записей: 996

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
hh.isna().sum()
# Out:
# Ищет работу на должность:          0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# Обновление резюме                  0
# Авто                               0
# Образование                        0
# Пол                                0
# Возраст                            0
# Опыт работы (месяц)                4
# Город                              0
# Готовность к переезду              0
# Готовность к командировкам         0
# полная занятость                   0
# частичная занятость                0
# проектная работа                   0
# волонтерство                       0
# стажировка                         0
# гибкий график                      0
# полный день                        0
# сменный график                     0
# вахтовый метод                     0
# удаленная работа                   0
# ЗП (руб)                           0
# Опыт работы (год)                  4
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh = hh.dropna(how='any', axis=0, subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

hh = hh.fillna( {'Опыт работы (месяц)':hh['Опыт работы (месяц)'].median()})

print(hh.isna().sum(), end='\n\n')

print(hh['Опыт работы (месяц)'].mean())
# Out:
# Ищет работу на должность:          0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# Обновление резюме                  0
# Авто                               0
# Образование                        0
# Пол                                0
# Возраст                            0
# Опыт работы (месяц)                0
# Город                              0
# Готовность к переезду              0
# Готовность к командировкам         0
# полная занятость                   0
# частичная занятость                0
# проектная работа                   0
# волонтерство                       0
# стажировка                         0
# гибкий график                      0
# полный день                        0
# сменный график                     0
# вахтовый метод                     0
# удаленная работа                   0
# ЗП (руб)                           0
# Опыт работы (год)                  4
# dtype: int64
#
# 117.39558232931726

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
size = hh.shape[0]
print("Размер до очистки: ", size)
hh = hh.drop(hh[(hh['ЗП (руб)'] < 1000) |  (hh['ЗП (руб)'] > 1_000_000)].index)
print("Удалено выбросов: ", size - hh.shape[0])
# Out:
# Размер до очистки:  996
# Удалено выбросов:  3

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
size = hh.shape[0]
print("Размер до очистки: ", size)
hh = hh.drop(hh[(hh['Опыт работы (год)'] > hh['Возраст'])].index)
print("Удалено выбросов: ", size - hh.shape[0])
# Out:
# Размер до очистки:  993
# Удалено выбросов:  0

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

log_age= np.log(hh['Возраст'])

fig, ax = plt.subplots(1, 1, figsize=(16, 5))
histplot = sns.histplot(log_age, bins=50, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Log Age Distribution');

skw = log_age.skew()
if skw < 0:
    print('Skew: ', skw)
    print("Левосторонняя асиметрия")
elif skw > 0: 
    print('Skew: ', skw)
    print("Правосторонная асиметрия")
    
outliers, cleaned = outliers_z_score_mod(hh, 'Возраст', log_scale=True, left=3, right=4)
print(f'Число выбросов по методу z-отклонения mod: {outliers.shape[0]}')
print(f'Результирующее число записей mod: {cleaned.shape[0]}')
print(outliers['Возраст'])
# Out:
# Skew:  0.41893888716783023
# Правосторонная асиметрия
# Число выбросов по методу z-отклонения mod: 0
# Результирующее число записей mod: 993
# Series([], Name: Возраст, dtype: int64)

# %% [markdown]
# Мы преобразовали признак Возраста в логарфмированный вид, что бы привести его к  нормальному виду и мы могли воспользоваться методом z-отклонения для выявления выбросов.
#
# Как мы видим логарифмическое распредление ассимитрично в правую сторону.
#
# Затем мы применяем метод z-отклонений при этмо слева мы берем 3 сигмы, с справа 4. В итоге мы получили 3 выброса. Это записи с возрастом 15 и 100 лет. Первые слишком молоды, а послдений слшком высковозрастен. Эти записи мы исключили.
